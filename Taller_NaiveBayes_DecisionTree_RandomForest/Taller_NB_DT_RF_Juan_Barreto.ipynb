# %% [markdown]
# <a href="https://colab.research.google.com/github/jsebastianbarretoj99/Asignatura_Inteligencia_Artificial_5607/blob/master/Taller_NaiveBayes_DecisionTree_RandomForest/Taller_NB_DT_RF_Juan_Barreto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller: Naive Bayes y Decision Tree y Random Forest

# %% [markdown]
# Student: Juan Sebastián Barreto Jimenez

# %% [markdown]
# ## Libraries

# %%
# Imports of the necessary libraries
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn import tree
from sklearn.metrics import accuracy_score, f1_score, matthews_corrcoef
from matplotlib import pyplot as plt

# %% [markdown]
# ## Download Iris Flower Data Set

# %%
# Load Iris Flower
X_iris, y_iris = load_iris(return_X_y=True)
# Separate dataset in train and test|
X_train_p, X_test_p, y_train, y_test = train_test_split(X_iris, y_iris, test_size=0.25, random_state=0)
# Normalization of data
sc = StandardScaler()
sc.fit(X_train_p)
X_train = sc.transform(X_train_p)
X_test = sc.transform(X_test_p)

# %% [markdown]
# ## Implementation with Gaussian Naive Bayes Algorithm

# %%
gnb = GaussianNB() # Create model Naive Bayes Gaussian
gnb.fit(X_train, y_train) # Training of model
y_pred = gnb.predict(X_test)
print("Metrics of Naive Bayes Gaussian Model:")
print("Accuracy: "+ str(accuracy_score(y_test, y_pred)*100) + "%")
print("F1: "+ str(f1_score(y_test, y_pred, average='micro')*100) + "%")
print("MCC: "+ str(matthews_corrcoef(y_test, y_pred)*100) + "%")
# Out:
# Metrics of Naive Bayes Gaussian Model:
# Accuracy: 100.0%
# F1: 100.0%
# MCC: 100.0%

# %%
hyper_parameter_base = 1e-9
hyper_parameter_save = []
accuracy = []
f1 = []
mcc = []

for i in range(20):
    hyper_parameter = hyper_parameter_base*(10**i)
    hyper_parameter_save.append(hyper_parameter)
    gnb = GaussianNB(var_smoothing=hyper_parameter) # Create model Naive Bayes Gaussian
    gnb.fit(X_train, y_train) # Training of model
    y_pred = gnb.predict(X_test)
    accuracy.append(accuracy_score(y_test, y_pred)*100)
    f1.append(f1_score(y_test, y_pred, average='micro')*100)
    mcc.append(matthews_corrcoef(y_test, y_pred)*100)
print("Metrics of Naive Bayes Gaussian Model:")
# Accuracy of a Naive Bayes Gaussian Model
plt.semilogx(hyper_parameter_save, accuracy) # Plot accuracy vs hyper_parameter_save
plt.xlabel('Hyperparameter') # Set x label
plt.ylabel('Accuracy (%)') # Set y label
plt.title('Accuracy of a Naive Bayes Gaussian Model') # Set title
plt.xlim(1e-9, 1e10) # Set x limits
plt.grid() # On grid
plt.show() # Show graph
# F1 of a Naive Bayes Gaussian Model
plt.semilogx(hyper_parameter_save, f1) # Plot F1 vs hyper_parameter_save
plt.xlabel('Hyperparameter') # Set x label
plt.ylabel('F1 (%)') # Set y label
plt.title('F1 of a Naive Bayes Gaussian Model') # Set title
plt.xlim(1e-9, 1e10) # Set x limits
plt.grid() # On grid
plt.show() # Show graph
# MCC of a Naive Bayes Gaussian Model
plt.semilogx(hyper_parameter_save, mcc) # Plot mcc vs hyper_parameter_save
plt.xlabel('Hyperparameter') # Set x label
plt.ylabel('MCC (%)') # Set y label
plt.title('MCC of a Naive Bayes Gaussian Model') # Set title
plt.xlim(1e-9, 1e10) # Set x limits
plt.grid() # On grid
plt.show() # Show graph
# Out:
# Metrics of Naive Bayes Gaussian Model:

# %% [markdown]
# ## Implementation with Bernoulli Naive Bayes Algorithm

# %%
bnb = BernoulliNB() # Create model Naive Bayes Gaussian
bnb.fit(X_train, y_train) # Training of model
y_pred = bnb.predict(X_test)
print("Metrics of Naive Bayes Bernoulli Model:")
print("Accuracy: "+ str(accuracy_score(y_test, y_pred)*100) + "%")
print("F1: "+ str(f1_score(y_test, y_pred, average='micro')*100) + "%")
print("MCC: "+ str(matthews_corrcoef(y_test, y_pred)*100) + "%")
# Out:
# Metrics of Naive Bayes Bernoulli Model:
# Accuracy: 68.42105263157895%
# F1: 68.42105263157895%
# MCC: 57.2355485818823%

# %%
hyper_parameter_base = 1e-10
hyper_parameter_save = []
accuracy = []
f1 = []
mcc = []

for i in range(20):
    hyper_parameter = hyper_parameter_base*(10**i)
    hyper_parameter_save.append(hyper_parameter)
    bnb = BernoulliNB(alpha=hyper_parameter) # Create model Naive Bayes Bernoulli
    bnb.fit(X_train, y_train) # Training of model
    y_pred = bnb.predict(X_test)
    accuracy.append(accuracy_score(y_test, y_pred)*100)
    f1.append(f1_score(y_test, y_pred, average='micro')*100)
    mcc.append(matthews_corrcoef(y_test, y_pred)*100)
print("Metrics of Naive Bayes Bernoulli Model:")
# Accuracy of a Naive Bayes Bernoulli Model
plt.semilogx(hyper_parameter_save, accuracy) # Plot accuracy vs hyper_parameter_save
plt.xlabel('Hyperparameter') # Set x label
plt.ylabel('Accuracy (%)') # Set y label
plt.title('Accuracy of a Naive Bayes Bernoulli Model') # Set title
plt.xlim(1e-9, 1e10) # Set x limits
plt.grid() # On grid
plt.show() # Show graph
# F1 of a Naive Bayes Bernoulli Model
plt.semilogx(hyper_parameter_save, f1) # Plot F1 vs hyper_parameter_save
plt.xlabel('Hyperparameter') # Set x label
plt.ylabel('F1 (%)') # Set y label
plt.title('F1 of a Naive Bayes Bernoulli Model') # Set title
plt.xlim(1e-9, 1e10) # Set x limits
plt.grid() # On grid
plt.show() # Show graph
# MCC of a Naive Bayes Bernoulli Model
plt.semilogx(hyper_parameter_save, mcc) # Plot mcc vs hyper_parameter_save
plt.xlabel('Hyperparameter') # Set x label
plt.ylabel('MCC (%)') # Set y label
plt.title('MCC of a Naive Bayes Bernoulli Model') # Set title
plt.xlim(1e-9, 1e10) # Set x limits
plt.grid() # On grid
plt.show() # Show graph
# Out:
# Metrics of Naive Bayes Bernoulli Model:

# %% [markdown]
# ## Implementation with Decision Tree Algorithm

# %%
clf = tree.DecisionTreeClassifier() # Create model Decision Tree
clf.fit(X_train, y_train) # Training of model
tree.plot_tree(clf)
y_pred = clf.predict(X_test)
print("Metrics of Decision Tree model:")
print("Accuracy: "+ str(accuracy_score(y_test, y_pred)*100) + "%")
print("F1: "+ str(f1_score(y_test, y_pred, average='micro')*100) + "%")
print("MCC: "+ str(matthews_corrcoef(y_test, y_pred)*100) + "%")
print("\nTree training:")
# Out:
# Metrics of Decision Tree model:
# Accuracy: 97.36842105263158%
# F1: 97.36842105263158%
# MCC: 96.08244925752507%
#
# Tree training:

# %%
hyper_parameter_base = 0.1
hyper_parameter_save = []
accuracy = []
f1 = []
mcc = []

for i in range(20):
    hyper_parameter = hyper_parameter_base*i
    hyper_parameter_save.append(hyper_parameter)
    clf = tree.DecisionTreeClassifier(ccp_alpha=hyper_parameter) # Create model Tree Decision
    clf.fit(X_train, y_train) # Training of model
    y_pred = clf.predict(X_test)
    accuracy.append(accuracy_score(y_test, y_pred)*100)
    f1.append(f1_score(y_test, y_pred, average='micro')*100)
    mcc.append(matthews_corrcoef(y_test, y_pred)*100)
print("Metrics of Tree Decision Model:")
# Accuracy of a Tree Decision Model
plt.plot(hyper_parameter_save, accuracy) # Plot accuracy vs hyper_parameter_save
plt.xlabel('Hyperparameter') # Set x label
plt.ylabel('Accuracy (%)') # Set y label
plt.title('Accuracy of a Tree Decision Model') # Set title
plt.xlim(0, 1.9) # Set x limits
plt.grid() # On grid
plt.show() # Show graph
# F1 of a Tree Decision Model
plt.plot(hyper_parameter_save, f1) # Plot F1 vs hyper_parameter_save
plt.xlabel('Hyperparameter') # Set x label
plt.ylabel('F1 (%)') # Set y label
plt.title('F1 of a Tree Decision Model') # Set title
plt.xlim(0, 1.9) # Set x limits
plt.grid() # On grid
plt.show() # Show graph
# MCC of a Tree Decision Model
plt.plot(hyper_parameter_save, mcc) # Plot mcc vs hyper_parameter_save
plt.xlabel('Hyperparameter') # Set x label
plt.ylabel('MCC (%)') # Set y label
plt.title('MCC of a Tree Decision Model') # Set title
plt.xlim(0, 1.9) # Set x limits
plt.grid() # On grid
plt.show() # Show graph
# Out:
# Metrics of Tree Decision Model:
